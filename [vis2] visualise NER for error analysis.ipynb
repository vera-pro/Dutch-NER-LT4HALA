# %%
def get_index(cur_entry, tokens):
    ans = 0
    for i, tok in enumerate(tokens[:cur_entry['index']-1]):  # -1 because we start with [CLS]
        ans += len(tok.replace('#',''))  
        if i:
            ans += int(tok[0].isalpha())  # whitespace before every word (not subword or punctuation) except the first
        
    ans += cur_entry['word'][0].isalpha() # whitespace before our token (unless it's a subword)
    return ans

# Contains a dirty hack but oh well
def post_process(item):
    if item['word'].startswith('#'):
        item['entity'] = 'I' + item['entity'][1:]
    if item['word'].startswith('##'):
        item['entity'] = 'I' + item['entity'][1:]
    return item

def insert_index(item, tokens):
    item['start'] = get_index(item, tokens)  
    item['end'] = item['start']+len(item['word'].replace('#',''))
    return item

# %%
def is_first_word(token):
    return len(token) > 1 and token[0].isupper()

# %%
import string
def bio_tokens_to_text(bio_tokens):
    res = ''
    prev_token = ''
    for token in bio_tokens:
        if token in string.punctuation: # Hoi,
            res += token
        elif prev_token in string.punctuation and not is_first_word(token): # P.C. Hooft
            res += token
        else:
            res += ' '+token
        prev_token = token
    return res

# %%
'0' in string.punctuation
# Out:
# False

# %%
import spacy
from spacy import displacy
import seaborn as sns

def visualise(text, preds):
    ## Step 1: adding entities
    entities = []
    nlp = spacy.blank("nl")  # it should work with any language
    doc = nlp(text+' ') # a hack
    
    
    ner_map = {} 
    cur_type = ''
    cur_start, cur_end = 0, 0

    for pred in preds: 
        ent = pred['entity']
        if ent.startswith('B'): # or pred['start'] > cur_end+1: ## a dirty hack in case it failed to predict 'B'
            ## Adding the previous entity if it's not empty
            if cur_type != '':
                char_span = doc.char_span(cur_start, cur_end, cur_type, alignment_mode='expand')
                if char_span:
                    entities.append(char_span)

            ## Processing the new entity
            cur_type = ent[2:]
            if cur_type not in ner_map: 
                ner_map[cur_type] = len(ner_map)+1
            cur_start = pred['start']
            cur_end = pred['end']
        else: ## there's only 'B' and 'I', 'O' is not included
            cur_end = pred['end']

    ## Adding the last one
    if cur_type != '':
        char_span = doc.char_span(cur_start, cur_end, cur_type, alignment_mode='expand')
        if char_span:
            entities.append(char_span)
            
    doc.ents = entities
    
    ## Step 2: visualising 
    colours = sns.color_palette("Set2", len(ner_map)).as_hex()
    options = {"ents": list(ner_map.keys()),
               "colors": {ent: colours[ner_map[ent]-1] for ent in ner_map.keys()}
              }

    displacy_html = displacy.render(doc, style="ent", options=options,jupyter=True)

# %%
model_names = {'GysBERT': "/ivi/ilps/personal/vprovat/KB/models/GysBERT-NER-v2",
              'BERTje': "/ivi/ilps/personal/vprovat/KB/models/BERTje-NER-v2",
              'BERT-multi-cased': "/ivi/ilps/personal/vprovat/KB/models/BERT-multi-cased-NER-v2",
              'WikiNEuRal': "Babelscape/wikineural-multilingual-ner"}

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForTokenClassification


tokenizer = AutoTokenizer.from_pretrained(model_names['BERTje'])
model = AutoModelForTokenClassification.from_pretrained(model_names['BERTje'])
nlp = pipeline("ner", model=model, tokenizer=tokenizer)

example = "Ik ben Jip de Kip, en ik woon in Zandvoort aan Zee"

ner_results = nlp(example)
res = [post_process(item) for item in ner_results]
tokens = [tokenizer.decode(tok) for tok in tokenizer(example).input_ids][1:-1]
res_for_visualisation = [insert_index(item,tokens) for item in res]
visualise(example, res_for_visualisation)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ik ben
# <mark class="entity" style="background: #66c2a5; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jip de Kip
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , en ik woon in
# <mark class="entity" style="background: #fc8d62; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zandvoort aan Zee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  </div></span>

# %%
from data_utils import prepare_data, convert_to_dataset

tests = 'test_NHA.txt  test_RHC.txt  test_SA.txt  test_VOC.txt'.split()
# train and val are redundant but we need the labels, sooo
train = prepare_data('/ivi/ilps/personal/vprovat/KB/data/AITrainingset/Data/train.txt')
val = prepare_data('/ivi/ilps/personal/vprovat/KB/data/AITrainingset/Data/validation.txt')

tests_prepared = [
     prepare_data('/ivi/ilps/personal/vprovat/KB/data/AITrainingset/Data/'+test) for test in tests
]

label_list = sorted(list(set([token_data[1] for sentence in train for token_data in sentence if token_data])))
label_map = {label: i for i, label in enumerate(label_list)}
label2id = {label: i for i, label in enumerate(label_list)}
tests_prepared = [
     prepare_data('/ivi/ilps/personal/vprovat/KB/data/AITrainingset/Data/'+test) for test in tests
]
test_data = [convert_to_dataset(test, label_map)
             for test in tests_prepared]
# Out:
#   0%|          | 0/8040 [00:00<?, ?it/s]
#   0%|          | 0/2150 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/78 [00:00<?, ?it/s]
#   0%|          | 0/91 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/78 [00:00<?, ?it/s]
#   0%|          | 0/91 [00:00<?, ?it/s]

# %%
test_example = test_data[1][0]

tokenized_inputs = tokenizer(
        test_example["tokens"], truncation=True, is_split_into_words=True, padding=True, return_tensors='pt'
    )

preds = model(tokenized_inputs['input_ids'])

# %%
example = bio_tokens_to_text(test_example["tokens"])

# %%
example
# Out:
# 'R o Caze 3.2.17 ontvangen met de verhoging 17.02 agt guldens,twee Stuivers 07 8:2:2:en twaalf penningen. De Swart dens boven de Lusten Verzoeke van de H.r D Surangar nog een Gezegelde Kwitie by het Mandaat,wegens betaalde Staats bladen,staats Couranten Brieveport Eta in dato 13e feb:1815 ad \x8370 8. En dito van 31 Maart 1815 wegens de Bydragen ad 5 8. Gedaan en gepasseerd voor den voornoemden Notaris Mr.D. Suringar op den drie en Twintigsten December achttien Hondert veertien te Duurswold ten huize van Jan Binser Beets ma in tegenswoordigheid van de Heer Bernardus Brunes ma predikant te Wytyctem en Eeuwe Lieuwer van Leeuwe deurwaarder te Beetsterzwaag getuigen welke deeze benevens de Comparanten de weer schout deeze gemeente en den Notaris onder wien deeze verbleven is hebben getekend B: Brandsma derde en laatste Ten tweeden, Ida Alyda Berns,meerder jarig;ten derden, Hendrika Berns,meerderjarig,de twee laatstgenoemden zonder Beroep woonende te Huissen, Dochters van genoemden Peter Berns en wylen Hendrina De Raay;ten Vierden, Hendrik Spanbroek Arbeider woo nende te Bemmel,in kwaliteit van toeziende voogd,over genoemde minderjarige Petronella Berns,als daartoe verkozen by een behoorlijk Geregistreerd besluit van den Fa milieraad onder praesidie van den Heere vrederegter te Bem mel de dato achtsten Mei achttien honderd een en twintig.'

# %%
ner_results = nlp(example)
res = [post_process(item) for item in ner_results]
tokens = [tokenizer.decode(tok) for tok in tokenizer(example).input_ids][1:-1]
res_for_visualisation = [insert_index(item,tokens) for item in res]
visualise(example, res_for_visualisation)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">R o Caze 3.2.17 ontvangen met de verhoging 17.02 agt guldens,twee Stuivers 07 8:2:2:en twaalf penningen. De Swart dens boven de Lusten Verzoeke van de H.r D Surangar nog een Gezegelde Kwitie by het Mandaat,wegens betaalde Staats bladen,staats Couranten Brieveport Eta in dato
# <mark class="entity" style="background: #fc8d62; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13e feb:1815
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  ad 70 8. En dito
# <mark class="entity" style="background: #fc8d62; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     van 31 Maart
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  1815 wegens de Bydragen ad 5 8. Gedaan en gepasseerd voor den voornoemden Notaris Mr.D. Suringar op den drie en Twintigsten December achttien Hondert veertien te Duurswold ten huize van Jan Binser Beets ma in tegenswoordigheid van de Heer Bernardus Brunes ma predikant te Wytyctem en
# <mark class="entity" style="background: #66c2a5; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Eeuwe Lieuwer van
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  Leeuwe deurwaarder te Beetsterzwaag getuigen welke deeze benevens de Comparanten de weer schout deeze gemeente en den Notaris onder wien deeze verbleven is hebben getekend B: Brandsma derde en laatste Ten tweeden, Ida Alyda Berns,meerder jarig;ten derden, Hendrika Berns,meerderjarig,de twee laatstgenoemden zonder Beroep woonende te Huissen, Dochters van genoemden Peter Berns en wylen Hendrina De Raay;ten Vierden, Hendrik Spanbroek Arbeider woo nende te Bemmel,in kwaliteit van toeziende voogd,over genoemde minderjarige Petronella Berns,als daartoe verkozen by een behoorlijk Geregistreerd besluit van den Fa milieraad onder praesidie van den Heere vrederegter te Bem mel de dato achtsten Mei achttien honderd een en twintig. </div></span>

# %%
ner_results
# Out:
# [{'entity': 'I-LOC',
#   'score': 0.52973866,
#   'index': 48,
#   'word': 'Lust',
#   'start': 126,
#   'end': 130},
#  {'entity': 'B-PER',
#   'score': 0.6601863,
#   'index': 58,
#   'word': 'D',
#   'start': 154,
#   'end': 155},
#  {'entity': 'I-PER',
#   'score': 0.8020663,
#   'index': 59,
#   'word': 'Sur',
#   'start': 156,
#   'end': 159},
#  {'entity': 'I-PER',
#   'score': 0.48470655,
#   'index': 60,
#   'word': '##anga',
#   'start': 159,
#   'end': 163},
#  {'entity': 'I-PER',
#   'score': 0.57316226,
#   'index': 61,
#   'word': '##r',
#   'start': 163,
#   'end': 164},
#  {'entity': 'B-TIME',
#   'score': 0.9579203,
#   'index': 90,
#   'word': '13',
#   'start': 276,
#   'end': 278},
#  {'entity': 'I-TIME',
#   'score': 0.9172103,
#   'index': 91,
#   'word': '##e',
#   'start': 278,
#   'end': 279},
#  {'entity': 'I-TIME',
#   'score': 0.9334394,
#   'index': 92,
#   'word': 'f',
#   'start': 280,
#   'end': 281},
#  {'entity': 'I-TIME',
#   'score': 0.90537804,
#   'index': 93,
#   'word': '##e',
#   'start': 281,
#   'end': 282},
#  {'entity': 'I-TIME',
#   'score': 0.9261688,
#   'index': 94,
#   'word': '##b',
#   'start': 282,
#   'end': 283},
#  {'entity': 'I-TIME',
#   'score': 0.9523441,
#   'index': 95,
#   'word': ':',
#   'start': 283,
#   'end': 284},
#  {'entity': 'I-TIME',
#   'score': 0.9393735,
#   'index': 96,
#   'word': '18',
#   'start': 284,
#   'end': 286},
#  {'entity': 'I-TIME',
#   'score': 0.92264867,
#   'index': 97,
#   'word': '##15',
#   'start': 286,
#   'end': 288},
#  {'entity': 'B-TIME',
#   'score': 0.96871537,
#   'index': 107,
#   'word': '31',
#   'start': 307,
#   'end': 309},
#  {'entity': 'I-TIME',
#   'score': 0.94691455,
#   'index': 108,
#   'word': 'Maar',
#   'start': 310,
#   'end': 314},
#  {'entity': 'I-TIME',
#   'score': 0.9492379,
#   'index': 109,
#   'word': '##t',
#   'start': 314,
#   'end': 315},
#  {'entity': 'I-TIME',
#   'score': 0.9024092,
#   'index': 110,
#   'word': '18',
#   'start': 315,
#   'end': 317},
#  {'entity': 'I-TIME',
#   'score': 0.86272675,
#   'index': 111,
#   'word': '##15',
#   'start': 317,
#   'end': 319},
#  {'entity': 'B-PER',
#   'score': 0.974227,
#   'index': 134,
#   'word': 'D',
#   'start': 399,
#   'end': 400},
#  {'entity': 'I-PER',
#   'score': 0.9663006,
#   'index': 135,
#   'word': '.',
#   'start': 400,
#   'end': 401},
#  {'entity': 'I-PER',
#   'score': 0.848478,
#   'index': 136,
#   'word': 'Sur',
#   'start': 402,
#   'end': 405},
#  {'entity': 'I-PER',
#   'score': 0.66989577,
#   'index': 137,
#   'word': '##inga',
#   'start': 405,
#   'end': 409},
#  {'entity': 'I-PER',
#   'score': 0.6190213,
#   'index': 138,
#   'word': '##r',
#   'start': 409,
#   'end': 410},
#  {'entity': 'B-TIME',
#   'score': 0.9831244,
#   'index': 142,
#   'word': 'drie',
#   'start': 418,
#   'end': 422},
#  {'entity': 'I-TIME',
#   'score': 0.9410243,
#   'index': 143,
#   'word': 'en',
#   'start': 423,
#   'end': 425},
#  {'entity': 'I-TIME',
#   'score': 0.93587375,
#   'index': 144,
#   'word': 'Twintig',
#   'start': 426,
#   'end': 433},
#  {'entity': 'I-TIME',
#   'score': 0.80446154,
#   'index': 145,
#   'word': '##sten',
#   'start': 433,
#   'end': 437},
#  {'entity': 'I-TIME',
#   'score': 0.79906213,
#   'index': 146,
#   'word': 'December',
#   'start': 438,
#   'end': 446},
#  {'entity': 'I-TIME',
#   'score': 0.8658511,
#   'index': 147,
#   'word': 'achttien',
#   'start': 447,
#   'end': 455},
#  {'entity': 'I-TIME',
#   'score': 0.5153,
#   'index': 148,
#   'word': 'Hond',
#   'start': 456,
#   'end': 460},
#  {'entity': 'I-TIME',
#   'score': 0.6327898,
#   'index': 149,
#   'word': '##er',
#   'start': 460,
#   'end': 462},
#  {'entity': 'I-TIME',
#   'score': 0.78084433,
#   'index': 150,
#   'word': '##t',
#   'start': 462,
#   'end': 463},
#  {'entity': 'I-TIME',
#   'score': 0.8958087,
#   'index': 151,
#   'word': 'veertien',
#   'start': 464,
#   'end': 472},
#  {'entity': 'B-LOC',
#   'score': 0.9752876,
#   'index': 153,
#   'word': 'Duur',
#   'start': 476,
#   'end': 480},
#  {'entity': 'I-LOC',
#   'score': 0.8156547,
#   'index': 154,
#   'word': '##s',
#   'start': 480,
#   'end': 481},
#  {'entity': 'I-LOC',
#   'score': 0.60573775,
#   'index': 155,
#   'word': '##wold',
#   'start': 481,
#   'end': 485},
#  {'entity': 'B-PER',
#   'score': 0.99372876,
#   'index': 160,
#   'word': 'Jan',
#   'start': 500,
#   'end': 503},
#  {'entity': 'I-PER',
#   'score': 0.9554689,
#   'index': 161,
#   'word': 'Bin',
#   'start': 504,
#   'end': 507},
#  {'entity': 'I-PER',
#   'score': 0.59171313,
#   'index': 162,
#   'word': '##s',
#   'start': 507,
#   'end': 508},
#  {'entity': 'I-PER',
#   'score': 0.6359207,
#   'index': 163,
#   'word': '##er',
#   'start': 508,
#   'end': 510},
#  {'entity': 'I-PER',
#   'score': 0.7910964,
#   'index': 164,
#   'word': 'Be',
#   'start': 511,
#   'end': 513},
#  {'entity': 'I-PER',
#   'score': 0.65905106,
#   'index': 165,
#   'word': '##ets',
#   'start': 513,
#   'end': 516},
#  {'entity': 'B-PER',
#   'score': 0.754682,
#   'index': 166,
#   'word': 'ma',
#   'start': 517,
#   'end': 519},
#  {'entity': 'B-PER',
#   'score': 0.9934881,
#   'index': 175,
#   'word': 'Bernard',
#   'start': 553,
#   'end': 560},
#  {'entity': 'I-PER',
#   'score': 0.7876834,
#   'index': 176,
#   'word': '##us',
#   'start': 560,
#   'end': 562},
#  {'entity': 'I-PER',
#   'score': 0.84630257,
#   'index': 177,
#   'word': 'Brun',
#   'start': 563,
#   'end': 567},
#  {'entity': 'I-PER',
#   'score': 0.6040446,
#   'index': 178,
#   'word': '##e',
#   'start': 567,
#   'end': 568},
#  {'entity': 'I-PER',
#   'score': 0.5279974,
#   'index': 179,
#   'word': '##s',
#   'start': 568,
#   'end': 569},
#  {'entity': 'B-LOC',
#   'score': 0.97738224,
#   'index': 183,
#   'word': 'Wy',
#   'start': 586,
#   'end': 588},
#  {'entity': 'I-LOC',
#   'score': 0.7003778,
#   'index': 184,
#   'word': '##t',
#   'start': 588,
#   'end': 589},
#  {'entity': 'I-LOC',
#   'score': 0.53858554,
#   'index': 185,
#   'word': '##y',
#   'start': 589,
#   'end': 590},
#  {'entity': 'I-LOC',
#   'score': 0.51297563,
#   'index': 186,
#   'word': '##c',
#   'start': 590,
#   'end': 591},
#  {'entity': 'I-LOC',
#   'score': 0.50205606,
#   'index': 187,
#   'word': '##te',
#   'start': 591,
#   'end': 593},
#  {'entity': 'I-LOC',
#   'score': 0.7298621,
#   'index': 188,
#   'word': '##m',
#   'start': 593,
#   'end': 594},
#  {'entity': 'I-LOC',
#   'score': 0.6614187,
#   'index': 189,
#   'word': 'en',
#   'start': 595,
#   'end': 597},
#  {'entity': 'B-LOC',
#   'score': 0.5330904,
#   'index': 190,
#   'word': 'Eeuw',
#   'start': 598,
#   'end': 602},
#  {'entity': 'B-PER',
#   'score': 0.9664169,
#   'index': 192,
#   'word': 'Li',
#   'start': 604,
#   'end': 606},
#  {'entity': 'I-PER',
#   'score': 0.8982944,
#   'index': 193,
#   'word': '##e',
#   'start': 606,
#   'end': 607},
#  {'entity': 'I-PER',
#   'score': 0.7110058,
#   'index': 194,
#   'word': '##uwer',
#   'start': 607,
#   'end': 611},
#  {'entity': 'I-PER',
#   'score': 0.94459933,
#   'index': 195,
#   'word': 'van',
#   'start': 612,
#   'end': 615},
#  {'entity': 'I-PER',
#   'score': 0.95615155,
#   'index': 196,
#   'word': 'Leeuw',
#   'start': 616,
#   'end': 621},
#  {'entity': 'B-LOC',
#   'score': 0.97866404,
#   'index': 200,
#   'word': 'Be',
#   'start': 638,
#   'end': 640},
#  {'entity': 'I-LOC',
#   'score': 0.917215,
#   'index': 201,
#   'word': '##ets',
#   'start': 640,
#   'end': 643},
#  {'entity': 'I-LOC',
#   'score': 0.67530227,
#   'index': 202,
#   'word': '##ter',
#   'start': 643,
#   'end': 646},
#  {'entity': 'I-LOC',
#   'score': 0.63035876,
#   'index': 203,
#   'word': '##zw',
#   'start': 646,
#   'end': 648},
#  {'entity': 'I-LOC',
#   'score': 0.56224006,
#   'index': 204,
#   'word': '##aag',
#   'start': 648,
#   'end': 651},
#  {'entity': 'B-PER',
#   'score': 0.97702,
#   'index': 241,
#   'word': 'B',
#   'start': 788,
#   'end': 789},
#  {'entity': 'I-PER',
#   'score': 0.9334842,
#   'index': 242,
#   'word': ':',
#   'start': 789,
#   'end': 790},
#  {'entity': 'I-PER',
#   'score': 0.9587891,
#   'index': 243,
#   'word': 'Brand',
#   'start': 791,
#   'end': 796},
#  {'entity': 'I-PER',
#   'score': 0.86548895,
#   'index': 244,
#   'word': '##sma',
#   'start': 796,
#   'end': 799},
#  {'entity': 'B-PER',
#   'score': 0.9861179,
#   'index': 252,
#   'word': 'Ida',
#   'start': 830,
#   'end': 833},
#  {'entity': 'I-PER',
#   'score': 0.94379103,
#   'index': 253,
#   'word': 'Al',
#   'start': 834,
#   'end': 836},
#  {'entity': 'I-PER',
#   'score': 0.6298832,
#   'index': 254,
#   'word': '##y',
#   'start': 836,
#   'end': 837},
#  {'entity': 'I-PER',
#   'score': 0.741175,
#   'index': 255,
#   'word': '##da',
#   'start': 837,
#   'end': 839},
#  {'entity': 'I-PER',
#   'score': 0.91205394,
#   'index': 256,
#   'word': 'Bern',
#   'start': 840,
#   'end': 844},
#  {'entity': 'I-PER',
#   'score': 0.5054543,
#   'index': 257,
#   'word': '##s',
#   'start': 844,
#   'end': 845},
#  {'entity': 'B-PER',
#   'score': 0.99096197,
#   'index': 268,
#   'word': 'Hendrik',
#   'start': 874,
#   'end': 881},
#  {'entity': 'I-PER',
#   'score': 0.82059664,
#   'index': 269,
#   'word': '##a',
#   'start': 881,
#   'end': 882},
#  {'entity': 'I-PER',
#   'score': 0.9076828,
#   'index': 270,
#   'word': 'Bern',
#   'start': 883,
#   'end': 887},
#  {'entity': 'I-PER',
#   'score': 0.57901645,
#   'index': 271,
#   'word': '##s',
#   'start': 887,
#   'end': 888},
#  {'entity': 'B-LOC',
#   'score': 0.71360254,
#   'index': 284,
#   'word': 'Huis',
#   'start': 954,
#   'end': 958},
#  {'entity': 'I-LOC',
#   'score': 0.6896502,
#   'index': 285,
#   'word': '##s',
#   'start': 958,
#   'end': 959},
#  {'entity': 'B-PER',
#   'score': 0.995939,
#   'index': 293,
#   'word': 'Peter',
#   'start': 986,
#   'end': 991},
#  {'entity': 'I-PER',
#   'score': 0.87560165,
#   'index': 294,
#   'word': 'Bern',
#   'start': 992,
#   'end': 996},
#  {'entity': 'I-PER',
#   'score': 0.6003567,
#   'index': 295,
#   'word': '##s',
#   'start': 996,
#   'end': 997},
#  {'entity': 'B-PER',
#   'score': 0.99494153,
#   'index': 300,
#   'word': 'Hen',
#   'start': 1007,
#   'end': 1010},
#  {'entity': 'I-PER',
#   'score': 0.62698394,
#   'index': 301,
#   'word': '##dri',
#   'start': 1010,
#   'end': 1013},
#  {'entity': 'I-PER',
#   'score': 0.8153689,
#   'index': 302,
#   'word': '##na',
#   'start': 1013,
#   'end': 1015},
#  {'entity': 'I-PER',
#   'score': 0.8479798,
#   'index': 303,
#   'word': 'De',
#   'start': 1016,
#   'end': 1018},
#  {'entity': 'I-PER',
#   'score': 0.91603863,
#   'index': 304,
#   'word': 'Ra',
#   'start': 1019,
#   'end': 1021},
#  {'entity': 'I-PER',
#   'score': 0.71664166,
#   'index': 305,
#   'word': '##ay',
#   'start': 1021,
#   'end': 1023},
#  {'entity': 'B-PER',
#   'score': 0.9920406,
#   'index': 312,
#   'word': 'Hendrik',
#   'start': 1038,
#   'end': 1045},
#  {'entity': 'I-PER',
#   'score': 0.9229748,
#   'index': 313,
#   'word': 'Span',
#   'start': 1046,
#   'end': 1050},
#  {'entity': 'I-PER',
#   'score': 0.847785,
#   'index': 314,
#   'word': '##broek',
#   'start': 1050,
#   'end': 1055},
#  {'entity': 'B-LOC',
#   'score': 0.9684361,
#   'index': 322,
#   'word': 'Be',
#   'start': 1078,
#   'end': 1080},
#  {'entity': 'I-LOC',
#   'score': 0.89552057,
#   'index': 323,
#   'word': '##mmel',
#   'start': 1080,
#   'end': 1084},
#  {'entity': 'B-PER',
#   'score': 0.9956786,
#   'index': 337,
#   'word': 'Petro',
#   'start': 1147,
#   'end': 1152},
#  {'entity': 'I-PER',
#   'score': 0.5907538,
#   'index': 338,
#   'word': '##nell',
#   'start': 1152,
#   'end': 1156},
#  {'entity': 'I-PER',
#   'score': 0.8002592,
#   'index': 339,
#   'word': '##a',
#   'start': 1156,
#   'end': 1157},
#  {'entity': 'I-PER',
#   'score': 0.8964542,
#   'index': 340,
#   'word': 'Bern',
#   'start': 1158,
#   'end': 1162},
#  {'entity': 'I-PER',
#   'score': 0.67691016,
#   'index': 341,
#   'word': '##s',
#   'start': 1162,
#   'end': 1163},
#  {'entity': 'B-LOC',
#   'score': 0.92464674,
#   'index': 377,
#   'word': 'Be',
#   'start': 1292,
#   'end': 1294},
#  {'entity': 'I-LOC',
#   'score': 0.7968641,
#   'index': 378,
#   'word': '##m',
#   'start': 1294,
#   'end': 1295},
#  {'entity': 'B-LOC',
#   'score': 0.9269297,
#   'index': 379,
#   'word': 'me',
#   'start': 1296,
#   'end': 1298},
#  {'entity': 'I-LOC',
#   'score': 0.71319187,
#   'index': 380,
#   'word': '##l',
#   'start': 1298,
#   'end': 1299},
#  {'entity': 'B-TIME',
#   'score': 0.97784984,
#   'index': 384,
#   'word': 'achtste',
#   'start': 1308,
#   'end': 1315},
#  {'entity': 'I-TIME',
#   'score': 0.8540663,
#   'index': 385,
#   'word': '##n',
#   'start': 1315,
#   'end': 1316},
#  {'entity': 'I-TIME',
#   'score': 0.8625185,
#   'index': 386,
#   'word': 'Mei',
#   'start': 1317,
#   'end': 1320},
#  {'entity': 'I-TIME',
#   'score': 0.9346043,
#   'index': 387,
#   'word': 'achttien',
#   'start': 1321,
#   'end': 1329},
#  {'entity': 'I-TIME',
#   'score': 0.8221948,
#   'index': 388,
#   'word': 'honderd',
#   'start': 1330,
#   'end': 1337},
#  {'entity': 'I-TIME',
#   'score': 0.9066717,
#   'index': 389,
#   'word': 'een',
#   'start': 1338,
#   'end': 1341},
#  {'entity': 'I-TIME',
#   'score': 0.952095,
#   'index': 390,
#   'word': 'en',
#   'start': 1342,
#   'end': 1344},
#  {'entity': 'I-TIME',
#   'score': 0.9221805,
#   'index': 391,
#   'word': 'twintig',
#   'start': 1345,
#   'end': 1352},
#  {'entity': 'I-TIME',
#   'score': 0.5041871,
#   'index': 392,
#   'word': '.',
#   'start': 1352,
#   'end': 1353}]

# %%
res_for_visualisation
# Out:
# [{'entity': 'I-LOC',
#   'score': 0.52973866,
#   'index': 48,
#   'word': 'Lust',
#   'start': 126,
#   'end': 130},
#  {'entity': 'B-PER',
#   'score': 0.6601863,
#   'index': 58,
#   'word': 'D',
#   'start': 154,
#   'end': 155},
#  {'entity': 'I-PER',
#   'score': 0.8020663,
#   'index': 59,
#   'word': 'Sur',
#   'start': 156,
#   'end': 159},
#  {'entity': 'I-PER',
#   'score': 0.48470655,
#   'index': 60,
#   'word': '##anga',
#   'start': 159,
#   'end': 163},
#  {'entity': 'I-PER',
#   'score': 0.57316226,
#   'index': 61,
#   'word': '##r',
#   'start': 163,
#   'end': 164},
#  {'entity': 'B-TIME',
#   'score': 0.9579203,
#   'index': 90,
#   'word': '13',
#   'start': 276,
#   'end': 278},
#  {'entity': 'I-TIME',
#   'score': 0.9172103,
#   'index': 91,
#   'word': '##e',
#   'start': 278,
#   'end': 279},
#  {'entity': 'I-TIME',
#   'score': 0.9334394,
#   'index': 92,
#   'word': 'f',
#   'start': 280,
#   'end': 281},
#  {'entity': 'I-TIME',
#   'score': 0.90537804,
#   'index': 93,
#   'word': '##e',
#   'start': 281,
#   'end': 282},
#  {'entity': 'I-TIME',
#   'score': 0.9261688,
#   'index': 94,
#   'word': '##b',
#   'start': 282,
#   'end': 283},
#  {'entity': 'I-TIME',
#   'score': 0.9523441,
#   'index': 95,
#   'word': ':',
#   'start': 283,
#   'end': 284},
#  {'entity': 'I-TIME',
#   'score': 0.9393735,
#   'index': 96,
#   'word': '18',
#   'start': 284,
#   'end': 286},
#  {'entity': 'I-TIME',
#   'score': 0.92264867,
#   'index': 97,
#   'word': '##15',
#   'start': 286,
#   'end': 288},
#  {'entity': 'B-TIME',
#   'score': 0.96871537,
#   'index': 107,
#   'word': '31',
#   'start': 307,
#   'end': 309},
#  {'entity': 'I-TIME',
#   'score': 0.94691455,
#   'index': 108,
#   'word': 'Maar',
#   'start': 310,
#   'end': 314},
#  {'entity': 'I-TIME',
#   'score': 0.9492379,
#   'index': 109,
#   'word': '##t',
#   'start': 314,
#   'end': 315},
#  {'entity': 'I-TIME',
#   'score': 0.9024092,
#   'index': 110,
#   'word': '18',
#   'start': 315,
#   'end': 317},
#  {'entity': 'I-TIME',
#   'score': 0.86272675,
#   'index': 111,
#   'word': '##15',
#   'start': 317,
#   'end': 319},
#  {'entity': 'B-PER',
#   'score': 0.974227,
#   'index': 134,
#   'word': 'D',
#   'start': 399,
#   'end': 400},
#  {'entity': 'I-PER',
#   'score': 0.9663006,
#   'index': 135,
#   'word': '.',
#   'start': 400,
#   'end': 401},
#  {'entity': 'I-PER',
#   'score': 0.848478,
#   'index': 136,
#   'word': 'Sur',
#   'start': 402,
#   'end': 405},
#  {'entity': 'I-PER',
#   'score': 0.66989577,
#   'index': 137,
#   'word': '##inga',
#   'start': 405,
#   'end': 409},
#  {'entity': 'I-PER',
#   'score': 0.6190213,
#   'index': 138,
#   'word': '##r',
#   'start': 409,
#   'end': 410},
#  {'entity': 'B-TIME',
#   'score': 0.9831244,
#   'index': 142,
#   'word': 'drie',
#   'start': 418,
#   'end': 422},
#  {'entity': 'I-TIME',
#   'score': 0.9410243,
#   'index': 143,
#   'word': 'en',
#   'start': 423,
#   'end': 425},
#  {'entity': 'I-TIME',
#   'score': 0.93587375,
#   'index': 144,
#   'word': 'Twintig',
#   'start': 426,
#   'end': 433},
#  {'entity': 'I-TIME',
#   'score': 0.80446154,
#   'index': 145,
#   'word': '##sten',
#   'start': 433,
#   'end': 437},
#  {'entity': 'I-TIME',
#   'score': 0.79906213,
#   'index': 146,
#   'word': 'December',
#   'start': 438,
#   'end': 446},
#  {'entity': 'I-TIME',
#   'score': 0.8658511,
#   'index': 147,
#   'word': 'achttien',
#   'start': 447,
#   'end': 455},
#  {'entity': 'I-TIME',
#   'score': 0.5153,
#   'index': 148,
#   'word': 'Hond',
#   'start': 456,
#   'end': 460},
#  {'entity': 'I-TIME',
#   'score': 0.6327898,
#   'index': 149,
#   'word': '##er',
#   'start': 460,
#   'end': 462},
#  {'entity': 'I-TIME',
#   'score': 0.78084433,
#   'index': 150,
#   'word': '##t',
#   'start': 462,
#   'end': 463},
#  {'entity': 'I-TIME',
#   'score': 0.8958087,
#   'index': 151,
#   'word': 'veertien',
#   'start': 464,
#   'end': 472},
#  {'entity': 'B-LOC',
#   'score': 0.9752876,
#   'index': 153,
#   'word': 'Duur',
#   'start': 476,
#   'end': 480},
#  {'entity': 'I-LOC',
#   'score': 0.8156547,
#   'index': 154,
#   'word': '##s',
#   'start': 480,
#   'end': 481},
#  {'entity': 'I-LOC',
#   'score': 0.60573775,
#   'index': 155,
#   'word': '##wold',
#   'start': 481,
#   'end': 485},
#  {'entity': 'B-PER',
#   'score': 0.99372876,
#   'index': 160,
#   'word': 'Jan',
#   'start': 500,
#   'end': 503},
#  {'entity': 'I-PER',
#   'score': 0.9554689,
#   'index': 161,
#   'word': 'Bin',
#   'start': 504,
#   'end': 507},
#  {'entity': 'I-PER',
#   'score': 0.59171313,
#   'index': 162,
#   'word': '##s',
#   'start': 507,
#   'end': 508},
#  {'entity': 'I-PER',
#   'score': 0.6359207,
#   'index': 163,
#   'word': '##er',
#   'start': 508,
#   'end': 510},
#  {'entity': 'I-PER',
#   'score': 0.7910964,
#   'index': 164,
#   'word': 'Be',
#   'start': 511,
#   'end': 513},
#  {'entity': 'I-PER',
#   'score': 0.65905106,
#   'index': 165,
#   'word': '##ets',
#   'start': 513,
#   'end': 516},
#  {'entity': 'B-PER',
#   'score': 0.754682,
#   'index': 166,
#   'word': 'ma',
#   'start': 517,
#   'end': 519},
#  {'entity': 'B-PER',
#   'score': 0.9934881,
#   'index': 175,
#   'word': 'Bernard',
#   'start': 553,
#   'end': 560},
#  {'entity': 'I-PER',
#   'score': 0.7876834,
#   'index': 176,
#   'word': '##us',
#   'start': 560,
#   'end': 562},
#  {'entity': 'I-PER',
#   'score': 0.84630257,
#   'index': 177,
#   'word': 'Brun',
#   'start': 563,
#   'end': 567},
#  {'entity': 'I-PER',
#   'score': 0.6040446,
#   'index': 178,
#   'word': '##e',
#   'start': 567,
#   'end': 568},
#  {'entity': 'I-PER',
#   'score': 0.5279974,
#   'index': 179,
#   'word': '##s',
#   'start': 568,
#   'end': 569},
#  {'entity': 'B-LOC',
#   'score': 0.97738224,
#   'index': 183,
#   'word': 'Wy',
#   'start': 586,
#   'end': 588},
#  {'entity': 'I-LOC',
#   'score': 0.7003778,
#   'index': 184,
#   'word': '##t',
#   'start': 588,
#   'end': 589},
#  {'entity': 'I-LOC',
#   'score': 0.53858554,
#   'index': 185,
#   'word': '##y',
#   'start': 589,
#   'end': 590},
#  {'entity': 'I-LOC',
#   'score': 0.51297563,
#   'index': 186,
#   'word': '##c',
#   'start': 590,
#   'end': 591},
#  {'entity': 'I-LOC',
#   'score': 0.50205606,
#   'index': 187,
#   'word': '##te',
#   'start': 591,
#   'end': 593},
#  {'entity': 'I-LOC',
#   'score': 0.7298621,
#   'index': 188,
#   'word': '##m',
#   'start': 593,
#   'end': 594},
#  {'entity': 'I-LOC',
#   'score': 0.6614187,
#   'index': 189,
#   'word': 'en',
#   'start': 595,
#   'end': 597},
#  {'entity': 'B-LOC',
#   'score': 0.5330904,
#   'index': 190,
#   'word': 'Eeuw',
#   'start': 598,
#   'end': 602},
#  {'entity': 'B-PER',
#   'score': 0.9664169,
#   'index': 192,
#   'word': 'Li',
#   'start': 604,
#   'end': 606},
#  {'entity': 'I-PER',
#   'score': 0.8982944,
#   'index': 193,
#   'word': '##e',
#   'start': 606,
#   'end': 607},
#  {'entity': 'I-PER',
#   'score': 0.7110058,
#   'index': 194,
#   'word': '##uwer',
#   'start': 607,
#   'end': 611},
#  {'entity': 'I-PER',
#   'score': 0.94459933,
#   'index': 195,
#   'word': 'van',
#   'start': 612,
#   'end': 615},
#  {'entity': 'I-PER',
#   'score': 0.95615155,
#   'index': 196,
#   'word': 'Leeuw',
#   'start': 616,
#   'end': 621},
#  {'entity': 'B-LOC',
#   'score': 0.97866404,
#   'index': 200,
#   'word': 'Be',
#   'start': 638,
#   'end': 640},
#  {'entity': 'I-LOC',
#   'score': 0.917215,
#   'index': 201,
#   'word': '##ets',
#   'start': 640,
#   'end': 643},
#  {'entity': 'I-LOC',
#   'score': 0.67530227,
#   'index': 202,
#   'word': '##ter',
#   'start': 643,
#   'end': 646},
#  {'entity': 'I-LOC',
#   'score': 0.63035876,
#   'index': 203,
#   'word': '##zw',
#   'start': 646,
#   'end': 648},
#  {'entity': 'I-LOC',
#   'score': 0.56224006,
#   'index': 204,
#   'word': '##aag',
#   'start': 648,
#   'end': 651},
#  {'entity': 'B-PER',
#   'score': 0.97702,
#   'index': 241,
#   'word': 'B',
#   'start': 788,
#   'end': 789},
#  {'entity': 'I-PER',
#   'score': 0.9334842,
#   'index': 242,
#   'word': ':',
#   'start': 789,
#   'end': 790},
#  {'entity': 'I-PER',
#   'score': 0.9587891,
#   'index': 243,
#   'word': 'Brand',
#   'start': 791,
#   'end': 796},
#  {'entity': 'I-PER',
#   'score': 0.86548895,
#   'index': 244,
#   'word': '##sma',
#   'start': 796,
#   'end': 799},
#  {'entity': 'B-PER',
#   'score': 0.9861179,
#   'index': 252,
#   'word': 'Ida',
#   'start': 830,
#   'end': 833},
#  {'entity': 'I-PER',
#   'score': 0.94379103,
#   'index': 253,
#   'word': 'Al',
#   'start': 834,
#   'end': 836},
#  {'entity': 'I-PER',
#   'score': 0.6298832,
#   'index': 254,
#   'word': '##y',
#   'start': 836,
#   'end': 837},
#  {'entity': 'I-PER',
#   'score': 0.741175,
#   'index': 255,
#   'word': '##da',
#   'start': 837,
#   'end': 839},
#  {'entity': 'I-PER',
#   'score': 0.91205394,
#   'index': 256,
#   'word': 'Bern',
#   'start': 840,
#   'end': 844},
#  {'entity': 'I-PER',
#   'score': 0.5054543,
#   'index': 257,
#   'word': '##s',
#   'start': 844,
#   'end': 845},
#  {'entity': 'B-PER',
#   'score': 0.99096197,
#   'index': 268,
#   'word': 'Hendrik',
#   'start': 874,
#   'end': 881},
#  {'entity': 'I-PER',
#   'score': 0.82059664,
#   'index': 269,
#   'word': '##a',
#   'start': 881,
#   'end': 882},
#  {'entity': 'I-PER',
#   'score': 0.9076828,
#   'index': 270,
#   'word': 'Bern',
#   'start': 883,
#   'end': 887},
#  {'entity': 'I-PER',
#   'score': 0.57901645,
#   'index': 271,
#   'word': '##s',
#   'start': 887,
#   'end': 888},
#  {'entity': 'B-LOC',
#   'score': 0.71360254,
#   'index': 284,
#   'word': 'Huis',
#   'start': 954,
#   'end': 958},
#  {'entity': 'I-LOC',
#   'score': 0.6896502,
#   'index': 285,
#   'word': '##s',
#   'start': 958,
#   'end': 959},
#  {'entity': 'B-PER',
#   'score': 0.995939,
#   'index': 293,
#   'word': 'Peter',
#   'start': 986,
#   'end': 991},
#  {'entity': 'I-PER',
#   'score': 0.87560165,
#   'index': 294,
#   'word': 'Bern',
#   'start': 992,
#   'end': 996},
#  {'entity': 'I-PER',
#   'score': 0.6003567,
#   'index': 295,
#   'word': '##s',
#   'start': 996,
#   'end': 997},
#  {'entity': 'B-PER',
#   'score': 0.99494153,
#   'index': 300,
#   'word': 'Hen',
#   'start': 1007,
#   'end': 1010},
#  {'entity': 'I-PER',
#   'score': 0.62698394,
#   'index': 301,
#   'word': '##dri',
#   'start': 1010,
#   'end': 1013},
#  {'entity': 'I-PER',
#   'score': 0.8153689,
#   'index': 302,
#   'word': '##na',
#   'start': 1013,
#   'end': 1015},
#  {'entity': 'I-PER',
#   'score': 0.8479798,
#   'index': 303,
#   'word': 'De',
#   'start': 1016,
#   'end': 1018},
#  {'entity': 'I-PER',
#   'score': 0.91603863,
#   'index': 304,
#   'word': 'Ra',
#   'start': 1019,
#   'end': 1021},
#  {'entity': 'I-PER',
#   'score': 0.71664166,
#   'index': 305,
#   'word': '##ay',
#   'start': 1021,
#   'end': 1023},
#  {'entity': 'B-PER',
#   'score': 0.9920406,
#   'index': 312,
#   'word': 'Hendrik',
#   'start': 1038,
#   'end': 1045},
#  {'entity': 'I-PER',
#   'score': 0.9229748,
#   'index': 313,
#   'word': 'Span',
#   'start': 1046,
#   'end': 1050},
#  {'entity': 'I-PER',
#   'score': 0.847785,
#   'index': 314,
#   'word': '##broek',
#   'start': 1050,
#   'end': 1055},
#  {'entity': 'B-LOC',
#   'score': 0.9684361,
#   'index': 322,
#   'word': 'Be',
#   'start': 1078,
#   'end': 1080},
#  {'entity': 'I-LOC',
#   'score': 0.89552057,
#   'index': 323,
#   'word': '##mmel',
#   'start': 1080,
#   'end': 1084},
#  {'entity': 'B-PER',
#   'score': 0.9956786,
#   'index': 337,
#   'word': 'Petro',
#   'start': 1147,
#   'end': 1152},
#  {'entity': 'I-PER',
#   'score': 0.5907538,
#   'index': 338,
#   'word': '##nell',
#   'start': 1152,
#   'end': 1156},
#  {'entity': 'I-PER',
#   'score': 0.8002592,
#   'index': 339,
#   'word': '##a',
#   'start': 1156,
#   'end': 1157},
#  {'entity': 'I-PER',
#   'score': 0.8964542,
#   'index': 340,
#   'word': 'Bern',
#   'start': 1158,
#   'end': 1162},
#  {'entity': 'I-PER',
#   'score': 0.67691016,
#   'index': 341,
#   'word': '##s',
#   'start': 1162,
#   'end': 1163},
#  {'entity': 'B-LOC',
#   'score': 0.92464674,
#   'index': 377,
#   'word': 'Be',
#   'start': 1292,
#   'end': 1294},
#  {'entity': 'I-LOC',
#   'score': 0.7968641,
#   'index': 378,
#   'word': '##m',
#   'start': 1294,
#   'end': 1295},
#  {'entity': 'B-LOC',
#   'score': 0.9269297,
#   'index': 379,
#   'word': 'me',
#   'start': 1296,
#   'end': 1298},
#  {'entity': 'I-LOC',
#   'score': 0.71319187,
#   'index': 380,
#   'word': '##l',
#   'start': 1298,
#   'end': 1299},
#  {'entity': 'B-TIME',
#   'score': 0.97784984,
#   'index': 384,
#   'word': 'achtste',
#   'start': 1308,
#   'end': 1315},
#  {'entity': 'I-TIME',
#   'score': 0.8540663,
#   'index': 385,
#   'word': '##n',
#   'start': 1315,
#   'end': 1316},
#  {'entity': 'I-TIME',
#   'score': 0.8625185,
#   'index': 386,
#   'word': 'Mei',
#   'start': 1317,
#   'end': 1320},
#  {'entity': 'I-TIME',
#   'score': 0.9346043,
#   'index': 387,
#   'word': 'achttien',
#   'start': 1321,
#   'end': 1329},
#  {'entity': 'I-TIME',
#   'score': 0.8221948,
#   'index': 388,
#   'word': 'honderd',
#   'start': 1330,
#   'end': 1337},
#  {'entity': 'I-TIME',
#   'score': 0.9066717,
#   'index': 389,
#   'word': 'een',
#   'start': 1338,
#   'end': 1341},
#  {'entity': 'I-TIME',
#   'score': 0.952095,
#   'index': 390,
#   'word': 'en',
#   'start': 1342,
#   'end': 1344},
#  {'entity': 'I-TIME',
#   'score': 0.9221805,
#   'index': 391,
#   'word': 'twintig',
#   'start': 1345,
#   'end': 1352},
#  {'entity': 'I-TIME',
#   'score': 0.5041871,
#   'index': 392,
#   'word': '.',
#   'start': 1352,
#   'end': 1353}]

# %%
tokens = [tokenizer.decode(tok) for tok in tokenized_inputs['input_ids'][0]][1:-1]

# %%
# Out:
# ['R',
#  'o',
#  'Ca',
#  '##ze',
#  '3',
#  '.',
#  '2',
#  '.',
#  '17',
#  'ontvangen',
#  'met',
#  'de',
#  'verhoging',
#  '17',
#  '.',
#  '02',
#  'a',
#  '##g',
#  '##t',
#  'gulden',
#  '##s',
#  ',',
#  'twee',
#  'Stu',
#  '##ive',
#  '##r',
#  '##s',
#  '07',
#  '8',
#  ':',
#  '2',
#  ':',
#  '2',
#  ':',
#  'en',
#  'twaalf',
#  'pe',
#  '##nning',
#  '##en',
#  '.',
#  'De',
#  'Swart',
#  'de',
#  '##n',
#  '##s',
#  'boven',
#  'de',
#  'Lust',
#  '##en',
#  'Ver',
#  '##zoek',
#  '##e',
#  'van',
#  'de',
#  'H',
#  '.',
#  'r',
#  'D',
#  'Sur',
#  '##anga',
#  '##r',
#  'nog',
#  'een',
#  'Geze',
#  '##geld',
#  '##e',
#  'Kwi',
#  '##tie',
#  'by',
#  'het',
#  'Man',
#  '##da',
#  '##at',
#  ',',
#  'wegens',
#  'betaalde',
#  'Staats',
#  'bladen',
#  ',',
#  'staats',
#  'Courant',
#  '##en',
#  'Bri',
#  '##eve',
#  '##port',
#  'Eta',
#  'in',
#  'dat',
#  '##o',
#  '13',
#  '##e',
#  'f',
#  '##e',
#  '##b',
#  ':',
#  '18',
#  '##15',
#  'a',
#  '##d',
#  '70',
#  '8',
#  '.',
#  'En',
#  'dit',
#  '##o',
#  'van',
#  '31',
#  'Maar',
#  '##t',
#  '18',
#  '##15',
#  'wegens',
#  'de',
#  'By',
#  '##dragen',
#  'a',
#  '##d',
#  '5',
#  '8',
#  '.',
#  'Gedaan',
#  'en',
#  'gepasseerd',
#  'voor',
#  'de',
#  '##n',
#  'voor',
#  '##noemd',
#  '##en',
#  'Not',
#  '##aris',
#  'Mr',
#  '.',
#  'D',
#  '.',
#  'Sur',
#  '##inga',
#  '##r',
#  'op',
#  'de',
#  '##n',
#  'drie',
#  'en',
#  'Twintig',
#  '##sten',
#  'December',
#  'achttien',
#  'Hond',
#  '##er',
#  '##t',
#  'veertien',
#  'te',
#  'Duur',
#  '##s',
#  '##wold',
#  'te',
#  '##n',
#  'huize',
#  'van',
#  'Jan',
#  'Bin',
#  '##s',
#  '##er',
#  'Be',
#  '##ets',
#  'ma',
#  'in',
#  'tegen',
#  '##s',
#  '##woord',
#  '##igheid',
#  'van',
#  'de',
#  'Heer',
#  'Bernard',
#  '##us',
#  'Brun',
#  '##e',
#  '##s',
#  'ma',
#  'predikant',
#  'te',
#  'Wy',
#  '##t',
#  '##y',
#  '##c',
#  '##te',
#  '##m',
#  'en',
#  'Eeuw',
#  '##e',
#  'Li',
#  '##e',
#  '##uwer',
#  'van',
#  'Leeuw',
#  '##e',
#  'deurwaarder',
#  'te',
#  'Be',
#  '##ets',
#  '##ter',
#  '##zw',
#  '##aag',
#  'getuigen',
#  'welke',
#  'de',
#  '##e',
#  '##ze',
#  'ben',
#  '##even',
#  '##s',
#  'de',
#  'Comp',
#  '##ara',
#  '##n',
#  '##ten',
#  'de',
#  'weer',
#  'schout',
#  'de',
#  '##e',
#  '##ze',
#  'gemeente',
#  'en',
#  'de',
#  '##n',
#  'Not',
#  '##aris',
#  'onder',
#  'wie',
#  '##n',
#  'de',
#  '##e',
#  '##ze',
#  'ver',
#  '##bleven',
#  'is',
#  'hebben',
#  'getekend',
#  'B',
#  ':',
#  'Brand',
#  '##sma',
#  'derde',
#  'en',
#  'laatste',
#  'Ten',
#  'tweede',
#  '##n',
#  ',',
#  'Ida',
#  'Al',
#  '##y',
#  '##da',
#  'Bern',
#  '##s',
#  ',',
#  'meer',
#  '##der',
#  'jarig',
#  ';',
#  'te',
#  '##n',
#  'derde',
#  '##n',
#  ',',
#  'Hendrik',
#  '##a',
#  'Bern',
#  '##s',
#  ',',
#  'meerderjarig',
#  ',',
#  'de',
#  'twee',
#  'laatstgenoemde',
#  '##n',
#  'zonder',
#  'Beroep',
#  'woon',
#  '##ende',
#  'te',
#  'Huis',
#  '##s',
#  '##en',
#  ',',
#  'Dochter',
#  '##s',
#  'van',
#  'genoemde',
#  '##n',
#  'Peter',
#  'Bern',
#  '##s',
#  'en',
#  'w',
#  '##yle',
#  '##n',
#  'Hen',
#  '##dri',
#  '##na',
#  'De',
#  'Ra',
#  '##ay',
#  ';',
#  'te',
#  '##n',
#  'Vierde',
#  '##n',
#  ',',
#  'Hendrik',
#  'Span',
#  '##broek',
#  'Arbeid',
#  '##er',
#  'wo',
#  '##o',
#  'n',
#  '##ende',
#  'te',
#  'Be',
#  '##mmel',
#  ',',
#  'in',
#  'kwaliteit',
#  'van',
#  'toezien',
#  '##de',
#  'vo',
#  '##og',
#  '##d',
#  ',',
#  'over',
#  'genoemde',
#  'minderjarige',
#  'Petro',
#  '##nell',
#  '##a',
#  'Bern',
#  '##s',
#  ',',
#  'als',
#  'daartoe',
#  'verkozen',
#  'by',
#  'een',
#  'behoorlijk',
#  'Ger',
#  '##e',
#  '##g',
#  '##ist',
#  '##r',
#  '##eerd',
#  'besluit',
#  'van',
#  'de',
#  '##n',
#  'Fa',
#  'mil',
#  '##ier',
#  '##aad',
#  'onder',
#  'prae',
#  '##s',
#  '##idi',
#  '##e',
#  'van',
#  'de',
#  '##n',
#  'Heer',
#  '##e',
#  'vrede',
#  '##reg',
#  '##ter',
#  'te',
#  'Be',
#  '##m',
#  'me',
#  '##l',
#  'de',
#  'dat',
#  '##o',
#  'achtste',
#  '##n',
#  'Mei',
#  'achttien',
#  'honderd',
#  'een',
#  'en',
#  'twintig',
#  '.']

# %%
preds_clean = [np.argmax(pred.detach().numpy()) for pred in preds.logits[0]]

# %%
labels = test_example['ner_tags']

# %%
np.argmax(preds.logits[0][0].detach().numpy())
# Out:
# 6

# %%
tokenized_inputs[0][0]
# Out:
# tensor(1)

# %%
len(tokenized_inputs[0])
# Out:
# 394

# %%
len(preds.logits[0])
# Out:
# 394

# %%
preds

# %%
import numpy as np
preds = np.argmax(preds)

# %%
preds
# Out:
# 0

# %%
tests_prepared[1][0]
# Out:
# [['R', 'O'],
#  ['o', 'O'],
#  ['Caze', 'O'],
#  ['3', 'O'],
#  ['.', 'O'],
#  ['2', 'O'],
#  ['.', 'O'],
#  ['17', 'O'],
#  ['ontvangen', 'O'],
#  ['met', 'O'],
#  ['de', 'O'],
#  ['verhoging', 'O'],
#  ['17', 'O'],
#  ['.', 'O'],
#  ['02', 'O'],
#  ['agt', 'O'],
#  ['guldens', 'O'],
#  [',', 'O'],
#  ['twee', 'O'],
#  ['Stuivers', 'O'],
#  ['07', 'O'],
#  ['8', 'O'],
#  [':', 'O'],
#  ['2', 'O'],
#  [':', 'O'],
#  ['2', 'O'],
#  [':', 'O'],
#  ['en', 'O'],
#  ['twaalf', 'O'],
#  ['penningen', 'O'],
#  ['.', 'O'],
#  ['De', 'B-PER'],
#  ['Swart', 'I-PER'],
#  ['dens', 'O'],
#  ['boven', 'O'],
#  ['de', 'O'],
#  ['Lusten', 'O'],
#  ['Verzoeke', 'O'],
#  ['van', 'O'],
#  ['de', 'O'],
#  ['H', 'O'],
#  ['.', 'O'],
#  ['r', 'O'],
#  ['D', 'B-PER'],
#  ['Surangar', 'I-PER'],
#  ['nog', 'O'],
#  ['een', 'O'],
#  ['Gezegelde', 'O'],
#  ['Kwitie', 'O'],
#  ['by', 'O'],
#  ['het', 'O'],
#  ['Mandaat', 'O'],
#  [',', 'O'],
#  ['wegens', 'O'],
#  ['betaalde', 'O'],
#  ['Staats', 'O'],
#  ['bladen', 'O'],
#  [',', 'O'],
#  ['staats', 'O'],
#  ['Couranten', 'O'],
#  ['Brieveport', 'O'],
#  ['Eta', 'O'],
#  ['in', 'O'],
#  ['dato', 'O'],
#  ['13e', 'B-TIME'],
#  ['feb', 'I-TIME'],
#  [':', 'I-TIME'],
#  ['1815', 'I-TIME'],
#  ['ad', 'O'],
#  ['\x8370', 'O'],
#  ['8', 'O'],
#  ['.', 'O'],
#  ['En', 'O'],
#  ['dito', 'O'],
#  ['van', 'O'],
#  ['31', 'B-TIME'],
#  ['Maart', 'I-TIME'],
#  ['1815', 'I-TIME'],
#  ['wegens', 'O'],
#  ['de', 'O'],
#  ['Bydragen', 'O'],
#  ['ad', 'O'],
#  ['5', 'O'],
#  ['8', 'O'],
#  ['.', 'O'],
#  ['Gedaan', 'O'],
#  ['en', 'O'],
#  ['gepasseerd', 'O'],
#  ['voor', 'O'],
#  ['den', 'O'],
#  ['voornoemden', 'O'],
#  ['Notaris', 'O'],
#  ['Mr', 'O'],
#  ['.', 'O'],
#  ['D', 'O'],
#  ['.', 'O'],
#  ['Suringar', 'O'],
#  ['op', 'O'],
#  ['den', 'O'],
#  ['drie', 'O'],
#  ['en', 'O'],
#  ['Twintigsten', 'O'],
#  ['December', 'O'],
#  ['achttien', 'O'],
#  ['Hondert', 'O'],
#  ['veertien', 'O'],
#  ['te', 'O'],
#  ['Duurswold', 'B-LOC'],
#  ['ten', 'O'],
#  ['huize', 'O'],
#  ['van', 'O'],
#  ['Jan', 'B-PER'],
#  ['Binser', 'I-PER'],
#  ['Beets', 'I-PER'],
#  ['ma', 'B-PER'],
#  ['in', 'O'],
#  ['tegenswoordigheid', 'O'],
#  ['van', 'O'],
#  ['de', 'O'],
#  ['Heer', 'O'],
#  ['Bernardus', 'B-PER'],
#  ['Brunes', 'I-PER'],
#  ['ma', 'O'],
#  ['predikant', 'O'],
#  ['te', 'O'],
#  ['Wytyctem', 'B-LOC'],
#  ['en', 'O'],
#  ['Eeuwe', 'B-PER'],
#  ['Lieuwer', 'I-PER'],
#  ['van', 'I-PER'],
#  ['Leeuwe', 'I-PER'],
#  ['deurwaarder', 'O'],
#  ['te', 'O'],
#  ['Beetsterzwaag', 'B-LOC'],
#  ['getuigen', 'O'],
#  ['welke', 'O'],
#  ['deeze', 'O'],
#  ['benevens', 'O'],
#  ['de', 'O'],
#  ['Comparanten', 'O'],
#  ['de', 'O'],
#  ['weer', 'O'],
#  ['schout', 'O'],
#  ['deeze', 'O'],
#  ['gemeente', 'O'],
#  ['en', 'O'],
#  ['den', 'O'],
#  ['Notaris', 'O'],
#  ['onder', 'O'],
#  ['wien', 'O'],
#  ['deeze', 'O'],
#  ['verbleven', 'O'],
#  ['is', 'O'],
#  ['hebben', 'O'],
#  ['getekend', 'O'],
#  ['B', 'B-PER'],
#  [':', 'I-PER'],
#  ['Brandsma', 'I-PER'],
#  ['derde', 'O'],
#  ['en', 'O'],
#  ['laatste', 'O'],
#  ['Ten', 'O'],
#  ['tweeden', 'O'],
#  [',', 'O'],
#  ['Ida', 'B-PER'],
#  ['Alyda', 'I-PER'],
#  ['Berns', 'I-PER'],
#  [',', 'O'],
#  ['meerder', 'O'],
#  ['jarig', 'O'],
#  [';', 'O'],
#  ['ten', 'O'],
#  ['derden', 'O'],
#  [',', 'O'],
#  ['Hendrika', 'B-PER'],
#  ['Berns', 'I-PER'],
#  [',', 'O'],
#  ['meerderjarig', 'O'],
#  [',', 'O'],
#  ['de', 'O'],
#  ['twee', 'O'],
#  ['laatstgenoemden', 'O'],
#  ['zonder', 'O'],
#  ['Beroep', 'O'],
#  ['woonende', 'O'],
#  ['te', 'O'],
#  ['Huissen', 'B-LOC'],
#  [',', 'O'],
#  ['Dochters', 'O'],
#  ['van', 'O'],
#  ['genoemden', 'O'],
#  ['Peter', 'B-PER'],
#  ['Berns', 'I-PER'],
#  ['en', 'O'],
#  ['wylen', 'O'],
#  ['Hendrina', 'B-PER'],
#  ['De', 'B-PER'],
#  ['Raay', 'I-PER'],
#  [';', 'O'],
#  ['ten', 'O'],
#  ['Vierden', 'O'],
#  [',', 'O'],
#  ['Hendrik', 'B-PER'],
#  ['Spanbroek', 'I-PER'],
#  ['Arbeider', 'O'],
#  ['woo', 'O'],
#  ['nende', 'O'],
#  ['te', 'O'],
#  ['Bemmel', 'B-LOC'],
#  [',', 'O'],
#  ['in', 'O'],
#  ['kwaliteit', 'O'],
#  ['van', 'O'],
#  ['toeziende', 'O'],
#  ['voogd', 'O'],
#  [',', 'O'],
#  ['over', 'O'],
#  ['genoemde', 'O'],
#  ['minderjarige', 'O'],
#  ['Petronella', 'B-PER'],
#  ['Berns', 'I-PER'],
#  [',', 'O'],
#  ['als', 'O'],
#  ['daartoe', 'O'],
#  ['verkozen', 'O'],
#  ['by', 'O'],
#  ['een', 'O'],
#  ['behoorlijk', 'O'],
#  ['Geregistreerd', 'O'],
#  ['besluit', 'O'],
#  ['van', 'O'],
#  ['den', 'O'],
#  ['Fa', 'O'],
#  ['milieraad', 'O'],
#  ['onder', 'O'],
#  ['praesidie', 'O'],
#  ['van', 'O'],
#  ['den', 'O'],
#  ['Heere', 'O'],
#  ['vrederegter', 'O'],
#  ['te', 'O'],
#  ['Bem', 'B-LOC'],
#  ['mel', 'B-LOC'],
#  ['de', 'O'],
#  ['dato', 'O'],
#  ['achtsten', 'B-TIME'],
#  ['Mei', 'I-TIME'],
#  ['achttien', 'I-TIME'],
#  ['honderd', 'I-TIME'],
#  ['een', 'I-TIME'],
#  ['en', 'I-TIME'],
#  ['twintig', 'I-TIME'],
#  ['.', 'I-TIME']]

# %%
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ik ben
# <mark class="entity" style="background: #66c2a5; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jip de Kip
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , en ik woon in
# <mark class="entity" style="background: #fc8d62; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zandvoort aan Zee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  </div></span>

# %%
res_for_visualisation
# Out:
# [{'entity': 'B-PER',
#   'score': 0.97226703,
#   'index': 3,
#   'word': 'Ji',
#   'start': 7,
#   'end': 9},
#  {'entity': 'I-PER',
#   'score': 0.88010025,
#   'index': 4,
#   'word': '##p',
#   'start': 9,
#   'end': 10},
#  {'entity': 'I-PER',
#   'score': 0.9402657,
#   'index': 5,
#   'word': 'de',
#   'start': 11,
#   'end': 13},
#  {'entity': 'I-PER',
#   'score': 0.9643208,
#   'index': 6,
#   'word': 'Kip',
#   'start': 14,
#   'end': 17},
#  {'entity': 'B-LOC',
#   'score': 0.9677931,
#   'index': 12,
#   'word': 'De',
#   'start': 33,
#   'end': 35},
#  {'entity': 'I-LOC',
#   'score': 0.5306217,
#   'index': 13,
#   'word': '##n',
#   'start': 35,
#   'end': 36},
#  {'entity': 'B-LOC',
#   'score': 0.6800242,
#   'index': 14,
#   'word': 'Haag',
#   'start': 37,
#   'end': 41}]

# %%
example
# Out:
# 'Ik ben Jip de Kip, en ik woon in Zandvoort aan Zee'

# %%
for item in res_for_visualisation:
    if example[get_index(item,tokens)] != item['word'].replace('#','')[0]:
        print(get_index(item,tokens), example[get_index(item,tokens)], '!=', item['word'].replace('#','')[0])
#     if example[item['start']:item['end']-1] != item['word'].replace('#',''):
#         print(example[item['start']:item['end']-1],'!=', item['word'].replace('#',''))
# Out:
# Ik
# Current start:  2
# ben
# Current start:  6
# Ik
# Current start:  2
# ben
# Current start:  6
# Ji
# Current start:  9
# Ik
# Current start:  2
# ben
# Current start:  6
# Ji
# Current start:  9
# ##p
# Current start:  10
# Ik
# Current start:  2
# ben
# Current start:  6
# Ji
# Current start:  9
# ##p
# Current start:  10
# de
# Current start:  13
# Ik
# Current start:  2
# ben
# Current start:  6
# Ji
# Current start:  9
# ##p
# Current start:  10
# de
# Current start:  13
# Kip
# Current start:  17
# ,
# Current start:  18
# en
# Current start:  21
# ik
# Current start:  24
# woon
# Current start:  29
# in
# Current start:  32
# Ik
# Current start:  2
# ben
# Current start:  6
# Ji
# Current start:  9
# ##p
# Current start:  10
# de
# Current start:  13
# Kip
# Current start:  17
# ,
# Current start:  18
# en
# Current start:  21
# ik
# Current start:  24
# woon
# Current start:  29
# in
# Current start:  32
# Zandvoort
# Current start:  42
# Ik
# Current start:  2
# ben
# Current start:  6
# Ji
# Current start:  9
# ##p
# Current start:  10
# de
# Current start:  13
# Kip
# Current start:  17
# ,
# Current start:  18
# en
# Current start:  21
# ik
# Current start:  24
# woon
# Current start:  29
# in
# Current start:  32
# Zandvoort
# Current start:  42
# aan
# Current start:  46
# Ik
# Current start:  2
# ben
# Current start:  6
# Ji
# Current start:  9
# ##p
# Current start:  10
# de
# Current start:  13
# Kip
# Current start:  17
# ,
# Current start:  18
# en
# Current start:  21
# ik
# Current start:  24
# woon
# Current start:  29
# in
# Current start:  32
# Zandvoort
# Current start:  42
# aan
# Current start:  46
# Ze
# Current start:  49

# %%
'I'.isalpha()
# Out:
# True

# %%
tokens
# Out:
# ['Ik',
#  'ben',
#  'Ji',
#  '##p',
#  'de',
#  'Kip',
#  ',',
#  'en',
#  'ik',
#  'woon',
#  'in',
#  'Zandvoort',
#  'aan',
#  'Ze',
#  '##e']
